# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Need4Stream — 01_build_index\n",
    "Fill `monthly_panel_template.csv` with your data first. This notebook builds indices and engineered features."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": none,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "from pathlib import Path\n",
    "from src.indices import build_piracy_index, build_fragmentation_index, add_time_features, add_lags, add_rolling\n",
    "\n",
    "csv_in = Path('../data/processed/monthly_panel_template.csv')\n",
    "df = pd.read_csv(csv_in, parse_dates=['date']).sort_values('date')\n",
    "\n",
    "# 1) Ensure PiracyIndex exists (if not, compute from components)\n",
    "if 'PiracyIndex' not in df or df['PiracyIndex'].isna().all():\n",
    "    df = build_piracy_index(df)\n",
    "\n",
    "# 2) Ensure FragmentationIndex exists (if not, compute)\n",
    "if 'FragmentationIndex' not in df or df['FragmentationIndex'].isna().all():\n",
    "    df = build_fragmentation_index(df)\n",
    "\n",
    "# 3) Feature engineering\n",
    "df = add_time_features(df, 'date')\n",
    "df = add_lags(df, 'PiracyIndex', lags=(1,2,3))\n",
    "df = add_lags(df, 'PriceBasket', lags=(1,2,3))\n",
    "df = add_rolling(df, 'PiracyIndex', window=3)\n",
    "\n",
    "# 4) Save panel\n",
    "out_path = Path('../data/processed/monthly_panel.csv')\n",
    "df.to_csv(out_path, index=False)\n",
    "print('Saved:', out_path)\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 13
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Need4Stream — 01_build_index\n",
#       8     "Fill `monthly_panel_template.csv` with your data first. This notebook builds indices and engineered features."
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
# ---> 13    "execution_count": none,
#      14    "metadata": {},
#      15    "outputs": [],
#      16    "source": [
#      17     "import pandas as pd\n",
#      18     "from pathlib import Path\n",
#      19     "from src.indices import build_piracy_index, build_fragmentation_index, add_time_features, add_lags, add_rolling\n",
#      20     "\n",
#      21     "csv_in = Path('../data/processed/monthly_panel_template.csv')\n",
#      22     "df = pd.read_csv(csv_in, parse_dates=['date']).sort_values('date')\n",
#      23     "\n",
#      24     "# 1) Ensure PiracyIndex exists (if not, compute from components)\n",
#      25     "if 'PiracyIndex' not in df or df['PiracyIndex'].isna().all():\n",
#      26     "    df = build_piracy_index(df)\n",
#      27     "\n",
#      28     "# 2) Ensure FragmentationIndex exists (if not, compute)\n",
#      29     "if 'FragmentationIndex' not in df or df['FragmentationIndex'].isna().all():\n",
#      30     "    df = build_fragmentation_index(df)\n",
#      31     "\n",
#      32     "# 3) Feature engineering\n",
#      33     "df = add_time_features(df, 'date')\n",
#      34     "df = add_lags(df, 'PiracyIndex', lags=(1,2,3))\n",
#      35     "df = add_lags(df, 'PriceBasket', lags=(1,2,3))\n",
#      36     "df = add_rolling(df, 'PiracyIndex', window=3)\n",
#      37     "\n",
#      38     "# 4) Save panel\n",
#      39     "out_path = Path('../data/processed/monthly_panel.csv')\n",
#      40     "df.to_csv(out_path, index=False)\n",
#      41     "print('Saved:', out_path)\n"
#      42    ]
#      43   }
#      44  ],
#      45  "metadata": {
#      46   "kernelspec": {
#      47    "display_name": "Python 3",
#      48    "language": "python",
#      49    "name": "python3"
#      50   },
#      51   "language_info": {
#      52    "name": "python",
#      53    "version": "3.x"
#      54   }
#      55  },
#      56  "nbformat": 4,
#      57  "nbformat_minor": 5
#      58 }
#
# NameError: name 'none' is not defined
